# %% [markdown]
# <a href="https://colab.research.google.com/github/RafdhiFatoni/ISE-Data-Science-Academy/blob/main/Tugas%203%20DS%20Academy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## TUGAS - 3 (RRR TEAM)

# %% [markdown]
# Model Evaluation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# %%
lokasi_file = "/content/dataset3.csv"
df = pd.read_csv(lokasi_file)
df.head(5)
# Out:
#    Id  Age  Income      Home  Emp_length     Intent  Amount   Rate  Status  \
# 0   0   22   59000      RENT       123.0   PERSONAL   35000  16.02       1
# 1   1   21    9600       OWN         5.0  EDUCATION    1000  11.14       0
# 2   2   25    9600  MORTGAGE         1.0    MEDICAL    5500  12.87       1
# 3   3   23   65500      RENT         4.0    MEDICAL   35000  15.23       1
# 4   4   24   54400      RENT         8.0    MEDICAL   35000  14.27       1
#
#    Percent_income Default  Cred_length
# 0            0.59       Y            3
# 1            0.10       N            2
# 2            0.57       N            3
# 3            0.53       N            2
# 4            0.55       Y            4

# %%
X = df.drop("Status", axis=1)
y = df['Status']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=46)

print('Train Size : ', y_train.shape)
print('Test Size  : ', y_test.shape)
# Out:
# Train Size :  (27693,)
# Test Size  :  (4888,)

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-82714b9c5713> in <cell line: 2>()
#       1 scaler = StandardScaler()
# ----> 2 scaler.fit(X_train)
#       3
#       4 X_train_scaled = scaler.transform(X_train)
#       5 X_test_scaled = scaler.transform(X_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     822         # Reset internal state before fitting
#     823         self._reset()
# --> 824         return self.partial_fit(X, y, sample_weight)
#     825
#     826     def partial_fit(self, X, y=None, sample_weight=None):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     859
#     860         first_call = not hasattr(self, "n_samples_seen_")
# --> 861         X = self._validate_data(
#     862             X,
# ...
